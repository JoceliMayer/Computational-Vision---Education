# %% [markdown]
# # EEL7825 DIP

# %% [markdown]
# ## Introdução
# <a href="DIP-Introduction_Lesson_1.pdf"> Introdução PDF  </a> --
# <a href="https://psilaboratory.wordpress.com/introduction-do-digital-image-processing/"> PSILAB Intro </a> --
# <a href="https://psilaboratory.wordpress.com/basic-tools-libraries-and-frameworks-for-research-and-development-of-computational-vision/"> PSILAB TOOLS </a> --
# <a href="https://psilaboratory.wordpress.com/basic-operations-with-examples/"> PSILAB Basics </a>

# %% [markdown]
# ## Melhoria
# <a href="EnhancePart1.pdf"> Melhoria 1 PDF Pontual </a> --
# <a href="EnhancePart2.pdf"> Melhoria 2 PDF  Equalização </a> --
# <a href="EnhancePart3.pdf"> Melhoria 3 PDF Filtragem </a> --
# <a href="EnhancePart4.pdf"> Melhoria 4 PDF Fourier </a> --
# <a href="https://psilaboratory.wordpress.com/2d-fourier-transform-and-applications/"> PSILAB Fourier </a> --
# <a href="https://psilaboratory.wordpress.com/digital-image-enhancement-techniques/"> PSILAB Melhoria </a>

# %% [markdown]
# ## Morfologia
# <a href="Chapter9morpho.pdf">  Morfologia 1 PDF </a> --
# <a href="MorphoGray.pdf">  Morfologia 2 PDF </a> --
# <a href="https://psilaboratory.wordpress.com/mathematical-morphology-theory-and-techniques/"> PSILAB Morfologia </a>

# %% [markdown]
# ## Segmentação
# <a href="Chapter10Segment.pdf"> Segmentação 1 PDF </a> --
# <a href="Segment.pdf"> Segmentação 2 PDF </a> --
# <a href="https://psilaboratory.wordpress.com/image-segmentation/"> PSILAB SEGMENTAÇÃO </a>
#
# ### Snakes - Contornos Ativos
# <a href="slides_snakes/1.png"> Snakes 1 </a> --
# <a href="slides_snakes/2.png"> Snakes 2 </a> --
# <a href="slides_snakes/3.png"> Snakes 3 </a> --
# <a href="slides_snakes/4.png"> Snakes 4 </a> --
# <a href="slides_snakes/5.png"> Snakes 5 </a> --
# <a href="slides_snakes/6.png"> Snakes 6 </a> --
# <a href="slides_snakes/7.png"> Snakes 7 </a> --
# <a href="slides_snakes/8.png"> Snakes 8 </a> --
# <a href="slides_snakes/9.png"> Snakes 9 </a> --
# <a href="slides_snakes/10.png"> Snakes 10 </a> --
# <a href="slides_snakes/11.png"> Snakes 11 </a> --
# <a href="slides_snakes/12.png"> Snakes 12 </a> --
# <a href="slides_snakes/13.png"> Snakes 13 </a> --
# <a href="slides_snakes/14.png"> Snakes 14 </a> --
# <a href="slides_snakes/Example_snake_scikit_image.png"> Exemplo </a> --
# <a href="slides_snakes/plot_active_contours.py"> Código </a>
#
# ## Ultralytics
# <a href="seg_ultralytics/seg_bus.png"> Bus </a> --
# <a href="seg_ultralytics/seg_result.png"> Segmentado </a> --
# <a href="seg_ultralytics/seg_code.png"> Código </a> --
# <a href="seg_ultralytics/seg_page.png"> Ultralytics Page </a>

# %% [markdown]
# ## Visão Computacional e Análise de Imagens
# <a href="Slides_PR.pdf"> Intro Reconhecimento de Padrões PDF </a> --
# <a href="CNNs_intro_slides.pdf"> CNN PDF </a> --
# <a href="https://psilaboratory.wordpress.com/computational-vision-and-image-analysis/"> PSILAB Visão Computacional </a> --
# <a href="https://jocelimayer-cv.netlify.app/transfer_learning"> PSILAB Transfer Learning </a> --
# <a href="https://jocelimayer-cv.netlify.app/YOLO_Transfer_Learning"> PSILAB YOLO </a> --
# <a href="https://jocelimayer-cv.netlify.app/guia_Kaggle"> PSILAB Kaggle </a> --
# <a href="https://jocelimayer-cv.netlify.app/runpod_report"> PSILAB Runpod </a>
#
# ## Representação e Descrição de ROI
# <a href="Chapter11_RepDescr.pdf"> Representação 1 PDf </a> --
# <a href="RepresentacaoDescr.pdf"> Representação 2 PDf </a>
#
# ### Momentos
# <a href="slides_moments/M1.png"> Definição </a> --
# <a href="slides_moments/M2.png"> Momentos HU 1 </a> --
# <a href="slides_moments/M3.png"> Momentos HU 2</a> --
# <a href="slides_moments/M4.png"> Momentos HU 3</a> --
# <a href="slides_moments/M5.png"> Momentos HU 4</a> --
# <a href="slides_moments/M6.png"> Momentos HU 5</a>

# %% [markdown]
# # ATIVIDADES
#
# ## Introdução
#
# seguem materiais complementares para o estudo desta semana:
#
# -- Artigo introdutório ao tema:
# https://presencial.moodle.ufsc.br/mod/resource/view.php?id=1391228
#
# -- Manual da biblioteca OpenCv, essencial para o aprendizado e desenvolvimento dos projetos:
# https://presencial.moodle.ufsc.br/mod/resource/view.php?id=1391229
#
# -- Vídeo Introdutório:
# https://presencial.moodle.ufsc.br/mod/url/view.php?id=1391230
#
# -- Vídeo introdutório com resumo, pontos principais e questionário auto avaliativo:
# https://jocelimayer-cv.netlify.app/introductiondip
#
# -- Ferramentas básicas para o curso, incluindo, bibliotecas OPencv, Scikit-image, Scikit-learn, ambientes de edição e simulação, Google Colab: https://colab.research.google.com/ , Kraggle: https://www.kaggle.com/, Ambientes python: Conda - linux, Anaconda mac/windows: https://www.anaconda.com/download e muito mais, disponíveis no projeto "Repository of Computational Vision":
# https://psilaboratory.wordpress.com/basic-tools-libraries-and-frameworks-for-research-and-development-of-computational-vision/
#
# Para esta semana Recomendo instalar o ambiente python e a biblioteca Opencv e realizar as seguintes atividades: 1) gerar código em python para abrir uma imagem e mostrar na tela (pág 23 do manual Opencv) e executar o programa, estudar python via https://www.python.org/, estudar as funções básicas da biblioteca Opencv no manual, até pág 45.
#
# # Melhoria
#
# seguem as sugestões de estudo dirigido para os conteúdos apresentados esta semana.
#
# Slides sobre melhoria:
# -- https://presencial.moodle.ufsc.br/mod/folder/view.php?id=1391231
#
# Videos sobre melhoria:
# -- https://presencial.moodle.ufsc.br/mod/url/view.php?id=1391232
# -- https://presencial.moodle.ufsc.br/mod/url/view.php?id=1391233
#
# Materiais disponíveis no projeto "Repository of Computational Vision", videos com resumo, pontos principais e questionário auto avaliativo:
# -- https://psilaboratory.wordpress.com/digital-image-enhancement-techniques/
#
# Recomendo estudar o manual Opencv na seção 1.4 - Image Processing in OpenCV, pág 49, nos tópicos mnistrados:
# -- https://presencial.moodle.ufsc.br/mod/resource/view.php?id=1391229
#
# # Melhoria Fourier
#
# materiais sobre o assunto ministrado esta semana:
#
# Vídeos interativos:
# - https://presencial.moodle.ufsc.br/mod/url/view.php?id=1391234
# - https://presencial.moodle.ufsc.br/mod/url/view.php?id=1391235
#
# Materiais disponíveis no projeto "Repository of Computational Vision", videos com resumo, pontos principais e questionário auto avaliativo:
# -- https://psilaboratory.wordpress.com/2d-fourier-transform-and-applications/
#
# Recomendo estudar o manual Opencv na seção 1.4.11 - Fourier Transform in OpenCV, pág 126, nos tópicos mnistrados:
# -- https://presencial.moodle.ufsc.br/mod/resource/view.php?id=1391229
#
# # Morpfologia
#
# materiais sobre o assunto ministrado esta semana:
#
# Vídeos interativos:
# -- https://presencial.moodle.ufsc.br/mod/url/view.php?id=1391236
# -- https://presencial.moodle.ufsc.br/mod/url/view.php?id=1391237
# -- https://presencial.moodle.ufsc.br/mod/url/view.php?id=1391239
#
# Slides: https://presencial.moodle.ufsc.br/mod/resource/view.php?id=1391238
#
# Materiais disponíveis no projeto "Repository of Computational Vision", videos com resumo, pontos principais e questionário auto avaliativo:
# -- https://psilaboratory.wordpress.com/mathematical-morphology-theory-and-techniques/
#
# Recomendo estudar o manual Opencv na seção "1.4.5 Morphological Transformations" nos tópicos ministrados:
# -- https://presencial.moodle.ufsc.br/mod/resource/view.php?id=1391229
#
# Seguem orientações de como elaborar a proposta de projeto:
# -- https://presencial.moodle.ufsc.br/mod/resource/view.php?id=1391240
#
# Exemplos adicionais de códigos para processamento de imagens:
# -- https://presencial.moodle.ufsc.br/mod/folder/view.php?id=1391241
#
# # Segmentação
#
# materiais sobre o assunto ministrado esta semana:
#
# Vídeos interativos:
# - https://presencial.moodle.ufsc.br/mod/url/view.php?id=1391243
# - https://presencial.moodle.ufsc.br/mod/url/view.php?id=1391244
# - https://presencial.moodle.ufsc.br/mod/url/view.php?id=1391245
# - https://presencial.moodle.ufsc.br/mod/url/view.php?id=1391246
#
# Slides sobre segmentação:
# - https://presencial.moodle.ufsc.br/mod/url/view.php?id=1391246
#
# Recomendo discutir comigo antes de submeter a proposta do projeto, data limite: deve ser submetida até dia 24/abril no link:
# - https://presencial.moodle.ufsc.br/mod/assign/view.php?id=1391247
#
#
# Recomendo estudar o manual Opencv na seções: 1.4.2 Image Thresholding, 1.4.6 Image Gradients, 1.4.7 Canny Edge Detection, 1.4.13 Hough Line Transform, 1.4.14 Hough Circle Transform,
# 1.4.9 Contours in OpenCV, 1.4.15 Image Segmentation with Watershed Algorithm, 1.4.16 Interactive Foreground Extraction using GrabCut Algorithm.
#
#
# Materiais disponíveis no projeto "Repository of Computational Vision", videos com resumo, pontos principais e questionário auto avaliativo:
# - https://psilaboratory.wordpress.com/image-segmentation/
#
# # Classificação
#
# materiais sobre o assunto ministrado esta semana:
#
# Vídeos interativos:
# - https://presencial.moodle.ufsc.br/mod/url/view.php?id=1391248
# - https://presencial.moodle.ufsc.br/mod/url/view.php?id=1391249
#
# Slides sobre Reconhecimento de padrões e CNN:
# - https://presencial.moodle.ufsc.br/mod/folder/view.php?id=1391250
#
# Recomendo discutir comigo antes de submeter a proposta do projeto, data limite: deve ser submetida até dia 1/maio (reagendada) no link:
# - https://presencial.moodle.ufsc.br/mod/assign/view.php?id=1391247
#
# Recomendo estudar o manual Opencv na seções: 1.5 Feature Detection and Description, 1.6 Video Analysis, 1.8 Machine Learning.
#
# Recomendo estudar a biblioteca Scikit Learn, o site tme uma boa introdução para Classificação, Regressãp, Clusterização, etc.
# -- https://scikit-learn.org/stable/index.html
#
#
# Materiais disponíveis no projeto "Repository of Computational Vision", videos com resumo, pontos principais e questionário auto avaliativo:
# https://psilaboratory.wordpress.com/computational-vision-and-image-analysis/
#
# # Visão Computacional
#
# nesta quinta 07/05/26 o tópico de nossa aula será treinamento de redes CNN para visão computacional, transfer learning, exemplos com uso de modelos treinados para inferência YOLO, treinamento com base da dados CIFAR10, CIFAR100, transfer learning do modelo MobilenetV2 para base CIFAR10, reconhecimento de placas e caracteres, reconhecimento de faces.
# Reomendo o acesso no "Repository of Computational Vision Project, https://psilaboratory.wordpress.com/repository-of-computational-vision-project/ " destes tópicos: 1) Transfer Learning e 2) How to train new classes in YOLO from Ultralytics using Transfer Learning, By Joceli Mayer, (in Portuguese). Ao final da aula estarei a disposição auxiliar nos projetos em andamento.
#
# # Entregas
#
# estarei a disposição para tirar dúvidas através de video conferência ou pessoalmente, basta agendar quando necessário,
# as datas das entregas ficam definidas como:
#
# -- 29/06: Link de vídeo no Youtube explicando os objetivos, etapas, solução e resultados de seu projeto, entre 3 a 7 minutos de duração. Enviar somente via LINK MOODLE: https://presencial.moodle.ufsc.br/mod/assign/view.php?id=1391252
#
# -- 02/07: Apresentação presencial na quinta feira a noite das 18:20 até 22:00 se necessário. Apresentação de uns 5 minutos destacando objetivos, metodologia, dificuldades e resultados.
#
# -- 03/07: Entrega dos relatórios: notebook ou pdf com os detalhes, relatos e códigos. Enviar somente via LINK MOODLE: https://presencial.moodle.ufsc.br/mod/assign/view.php?id=1391253
